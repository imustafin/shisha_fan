# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

import json
import re
# Out:
# Using TensorFlow backend.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %%
BEFORE_START = '\0'
AFTER_END = '\1'
def preproc(s):
    s = BEFORE_START + s + AFTER_END
    s = re.sub(r'\[.*\|.*\]', ' ', s)
    s = re.sub(r'[«»]', '"', s)
    return s.lower()

SEQ_LENGTH = 40

# %%
def read_vk_json(s, post_likes_min=0):
    with open(s, 'r') as f:
        posts = json.load(f)

    texts = []
    for p in posts:
        ptext = p['text'].strip()
        if len(ptext) > SEQ_LENGTH and p['likesCount'] >= post_likes_min:
            texts.append(ptext)

        for c in p['comments']:
            ctext = c['text'].strip()
            if c['likesCount'] > 0 and len(ctext) > SEQ_LENGTH:
                texts.append(ctext)

    return [preproc(x) for x in texts]

# %%
kalik_texts = read_vk_json('data/kalikfan.json')
print('Number of Kalik samples:', len(kalik_texts))
# Out:
# Number of Kalik samples: 1795

# %%
jumoreski_texts = read_vk_json('data/jumoreski.json', 1600)
print('Number of Jumoreski samples:', len(jumoreski_texts))
# Out:
# Number of Jumoreski samples: 8788

# %%
texts = kalik_texts # + jumoreski_texts
print('texts:', len(texts))
# Out:
# texts: 1795

# %%
chars = sorted(list(set(''.join(texts))))
print('total chars before dropping rare:', len(chars))
# Out:
# total chars before dropping rare: 878

# %%
nums = {}
for c in chars:
    for t in texts:
        if c in t:
            if c not in nums:
                nums[c] = 0
            nums[c] += 1
            
MIN_OCCURANCES = 7

for c in chars:
    if nums[c] < MIN_OCCURANCES:
        texts = list(map(lambda t: t.replace(c, ''), texts))
            
nums = {}
for c in chars:
    for t in texts:
        if c in t:
            if c not in nums:
                nums[c] = 0
            nums[c] += 1
            
sorted( ((v,k) for k,v in nums.items()), reverse=False)
# Out:
# [(7, '☀'),
#  (7, '⛵'),
#  (7, '🌳'),
#  (7, '🍁'),
#  (7, '🍃'),
#  (7, '🍋'),
#  (7, '🍓'),
#  (7, '🏭'),
#  (7, '🐎'),
#  (7, '🐩'),
#  (7, '👁'),
#  (7, '👫'),
#  (7, '👷'),
#  (7, '💁'),
#  (7, '💊'),
#  (7, '💕'),
#  (7, '💰'),
#  (7, '😙'),
#  (7, '😚'),
#  (7, '😣'),
#  (7, '🙎'),
#  (7, '🚘'),
#  (7, '🚶'),
#  (7, '🤞'),
#  (7, '🤰'),
#  (7, '🥕'),
#  (7, '🧞'),
#  (7, '🧠'),
#  (8, '/'),
#  (8, '🇧'),
#  (8, '🇴'),
#  (8, '🌑'),
#  (8, '🏋'),
#  (8, '👈'),
#  (8, '👠'),
#  (8, '👪'),
#  (8, '💄'),
#  (8, '💎'),
#  (8, '💜'),
#  (8, '🔫'),
#  (8, '🔮'),
#  (8, '🗯'),
#  (8, '😒'),
#  (8, '😖'),
#  (8, '🤖'),
#  (8, '🤥'),
#  (8, '🤷'),
#  (8, '🥺'),
#  (8, '🦍'),
#  (9, '_'),
#  (9, 'v'),
#  (9, '⛄'),
#  (9, '🌞'),
#  (9, '🍒'),
#  (9, '🎤'),
#  (9, '🐲'),
#  (9, '💅'),
#  (9, '💔'),
#  (9, '💙'),
#  (9, '💧'),
#  (9, '💫'),
#  (9, '😥'),
#  (9, '😮'),
#  (9, '😻'),
#  (9, '🤑'),
#  (9, '🤟'),
#  (9, '🥝'),
#  (10, '6'),
#  (10, '8'),
#  (10, 'w'),
#  (10, '‼'),
#  (10, '⚡'),
#  (10, '🇪'),
#  (10, '🇭'),
#  (10, '🍆'),
#  (10, '🍺'),
#  (10, '🏃'),
#  (10, '🐔'),
#  (10, '🐰'),
#  (10, '👵'),
#  (10, '👸'),
#  (10, '🗣'),
#  (10, '😴'),
#  (10, '🙉'),
#  (10, '🙋'),
#  (10, '🤐'),
#  (10, '🤫'),
#  (10, '🤭'),
#  (10, '🥰'),
#  (10, '🥵'),
#  (11, '9'),
#  (11, '☠'),
#  (11, '✨'),
#  (11, '❌'),
#  (11, '🇲'),
#  (11, '🇹'),
#  (11, '🇿'),
#  (11, '🌝'),
#  (11, '🍅'),
#  (11, '🎅'),
#  (11, '💆'),
#  (11, '🙂'),
#  (11, '🙌'),
#  (11, '🤕'),
#  (11, '🤨'),
#  (12, '7'),
#  (12, 'x'),
#  (12, '❗'),
#  (12, '👺'),
#  (12, '👽'),
#  (12, '💯'),
#  (12, '🖤'),
#  (12, '😩'),
#  (12, '🚬'),
#  (13, '✋'),
#  (13, '🇾'),
#  (13, '🍊'),
#  (13, '🐇'),
#  (13, '👏'),
#  (13, '👧'),
#  (13, '😐'),
#  (13, '😠'),
#  (13, '🙊'),
#  (14, '🌍'),
#  (14, '😑'),
#  (14, '😘'),
#  (14, '😬'),
#  (14, '🙀'),
#  (14, '🙈'),
#  (14, '🤮'),
#  (14, '🥴'),
#  (15, 'f'),
#  (15, '👅'),
#  (15, '👮'),
#  (15, '💣'),
#  (15, '😓'),
#  (15, '😛'),
#  (15, '🙆'),
#  (16, '⛔'),
#  (16, '✈'),
#  (16, '🇰'),
#  (16, '🇵'),
#  (16, '🍌'),
#  (16, '😲'),
#  (16, '😸'),
#  (16, '🚀'),
#  (16, '🚫'),
#  (16, '🤧'),
#  (17, '5'),
#  (17, '🇨'),
#  (17, '🍑'),
#  (17, '👆'),
#  (17, '👦'),
#  (17, '💋'),
#  (17, '💦'),
#  (17, '🙄'),
#  (18, '👉'),
#  (18, '🤦'),
#  (18, '🥳'),
#  (19, '#'),
#  (19, '🕺'),
#  (19, '😭'),
#  (19, '😵'),
#  (20, '🇦'),
#  (20, '👬'),
#  (20, '💀'),
#  (20, '😢'),
#  (20, '🤛'),
#  (20, '🤝'),
#  (20, '🧐'),
#  (21, '👄'),
#  (21, '👯'),
#  (21, '👱'),
#  (21, '👴'),
#  (21, '👹'),
#  (21, '👿'),
#  (21, '💂'),
#  (21, '😔'),
#  (21, '🤜'),
#  (22, '🍉'),
#  (22, '🏳'),
#  (22, '👑'),
#  (22, '👻'),
#  (23, '🇸'),
#  (23, '🏽'),
#  (23, '👶'),
#  (24, 'g'),
#  (24, 'y'),
#  (24, '🏾'),
#  (25, 'ъ'),
#  (25, '⚠'),
#  (25, '🆘'),
#  (25, '🇮'),
#  (25, '🤯'),
#  (26, '🇫'),
#  (26, '🌫'),
#  (26, '🏿'),
#  (26, '😰'),
#  (26, '🤡'),
#  (27, '👳'),
#  (27, '💃'),
#  (27, '💩'),
#  (27, '😹'),
#  (27, '🙅'),
#  (27, '🤬'),
#  (28, '4'),
#  (28, '🇳'),
#  (29, 'h'),
#  (30, '🌚'),
#  (30, '🌬'),
#  (30, '🤗'),
#  (30, '🤘'),
#  (31, '✊'),
#  (31, '🌈'),
#  (32, '🤩'),
#  (34, 'c'),
#  (34, '👩'),
#  (34, '😨'),
#  (35, 'm'),
#  (35, '😇'),
#  (36, '😺'),
#  (37, 'b'),
#  (37, '🤓'),
#  (38, 'p'),
#  (38, '💥'),
#  (39, '👎'),
#  (39, '👨'),
#  (40, 'k'),
#  (40, 't'),
#  (42, '🇱'),
#  (42, '🤔'),
#  (43, '2'),
#  (43, '😝'),
#  (43, '🤤'),
#  (45, '3'),
#  (45, '👀'),
#  (48, '🔞'),
#  (49, 'u'),
#  (49, '😄'),
#  (49, '🤢'),
#  (50, '—'),
#  (50, '✌'),
#  (50, '🌪'),
#  (51, '1'),
#  (51, '🤠'),
#  (51, '🤪'),
#  (52, 'd'),
#  (53, '☺'),
#  (54, 'l'),
#  (55, 'i'),
#  (55, 'r'),
#  (56, 'n'),
#  (57, '0'),
#  (57, '❤'),
#  (57, '😳'),
#  (58, 's'),
#  (59, '☁'),
#  (61, 'o'),
#  (62, '😊'),
#  (62, '🙏'),
#  (64, '👊'),
#  (65, '😉'),
#  (66, '😼'),
#  (67, '😋'),
#  (69, '😏'),
#  (75, '🇺'),
#  (75, '😱'),
#  (76, 'e'),
#  (76, '😆'),
#  (80, '😜'),
#  (84, '😀'),
#  (86, 'a'),
#  (89, '🇷'),
#  (90, '😍'),
#  (91, '♂'),
#  (91, '👌'),
#  (91, '😡'),
#  (93, ':'),
#  (93, '♀'),
#  (94, '😌'),
#  (100, '🏼'),
#  (106, '😁'),
#  (111, '"'),
#  (112, '🔥'),
#  (129, '😃'),
#  (135, '💭'),
#  (136, '😤'),
#  (153, '☝'),
#  (162, '*'),
#  (173, '😂'),
#  (184, '('),
#  (185, '🍎'),
#  (190, '🤣'),
#  (195, '🍏'),
#  (197, '👍'),
#  (199, '\u200d'),
#  (202, '💪'),
#  (215, '🏻'),
#  (221, '😅'),
#  (222, '😈'),
#  (270, '️'),
#  (276, '😎'),
#  (289, '🤙'),
#  (300, '!'),
#  (350, '?'),
#  (379, '.'),
#  (403, '💨'),
#  (422, 'ё'),
#  (484, 'ф'),
#  (592, 'щ'),
#  (630, '-'),
#  (651, 'э'),
#  (658, 'ц'),
#  (751, ')'),
#  (783, '\n'),
#  (867, 'ю'),
#  (1075, 'ш'),
#  (1099, ','),
#  (1125, 'ж'),
#  (1147, 'х'),
#  (1299, 'з'),
#  (1328, 'г'),
#  (1340, 'й'),
#  (1389, 'ч'),
#  (1508, 'ь'),
#  (1523, 'ы'),
#  (1537, 'б'),
#  (1558, 'я'),
#  (1599, 'п'),
#  (1638, 'м'),
#  (1648, 'д'),
#  (1657, 'в'),
#  (1660, 'у'),
#  (1684, 'с'),
#  (1724, 'р'),
#  (1728, 'л'),
#  (1738, 'н'),
#  (1755, 'и'),
#  (1756, 'к'),
#  (1764, 'е'),
#  (1773, 'т'),
#  (1779, 'о'),
#  (1789, 'а'),
#  (1795, '\x00'),
#  (1795, '\x01'),
#  (1795, ' ')]

# %%
chars = sorted(list(set(''.join(texts))))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 346

# %%
# cut the text in semi-redundant sequences of maxlen characters
sentences = []
next_chars = []

for text in texts:
    t = [BEFORE_START] * (SEQ_LENGTH - 1) + list(text) + [AFTER_END] * SEQ_LENGTH
    for i in range(1, len(t) - SEQ_LENGTH, 1):
        sentences.append(t[i:i + SEQ_LENGTH])
        next_chars.append(t[i + SEQ_LENGTH])

# for i in range(0, len(text) - maxlen, step):
#     sentences.append(text[i: i + maxlen])
#     next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 402837

# %%
print('Vectorization...')
x = np.zeros((len(sentences), SEQ_LENGTH, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
# model.add(LSTM(32, input_shape=(SEQ_LENGTH, len(chars)), return_sequences=True))
# model.add(LSTM(32, input_shape=(SEQ_LENGTH, len(chars)), return_sequences=True))
model.add(LSTM(256))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# Build model...

# %%
optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.random.choice(np.arange(0, len(chars)), 1, False, preds)[0]

# %%
def on_epoch_end(epoch, _):
#     if epoch % 10 != 0:
#         return
    # Function invoked at end of each epoch. Prints generated text.
    print()
    # print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - SEQ_LENGTH - 1)
    
    diversity = 0.2
    
    # print('----- diversity:', diversity)

    generated = ''
    sentence = ''.join([BEFORE_START] * SEQ_LENGTH)

    finished_well = False
    for i in range(400):
        x_pred = np.zeros((1, SEQ_LENGTH, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        if next_char == AFTER_END:
            finished_well = True
            break

        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    if not finished_well:
        sys.stdout.write('@@@')
        sys.stdout.flush()
    print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=2048,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 402837/402837 [==============================] - 52s 129us/step - loss: 1.4601
#
#  это же настоящие русский кальянчик на кальянную придумывали на кальянчиком и без кальянчиком на кальянную и дымовая в дымном станем и дыма и дыма и на кальянную мало кальянчиком и кальянчик на кальянную и на кальянчиком на кальянную и на кальянную и на двойное яблоко 🍎🍏 и кальянчик на просто на кальянчиком и кальянчика на кальянчиком и под какой кальянчик по полной забивочки по полной кралечку по@@@
# Epoch 2/60
# 402837/402837 [==============================] - 52s 129us/step - loss: 1.4146
#
# а по сука в долгом кальянную просто просто под рукой кальянную с великим дымного дымного 💨 💨 💨 💨 💨 💨 💨 💨 💨 💨 💨 и вечером дымного дымного дымного дымного настроения по полном старовой кальяновой по кайфу по полном напасными кальянчика с просто на старовой полного кальянчика с под сказали как такой кальяном по семе на своим дымных дымком 💨 💨 💨 💨 💨 💨 💨 💨 на делает как понимают по кальянную и на старо@@@
# Epoch 3/60
# 402837/402837 [==============================] - 52s 130us/step - loss: 1.3692
#
# пока мы с кальянной запасиков и подымить кальянчиком и сделал кальянщика и покурим кальянчиком подымить по полной кальянбусик на кальянбусик и себе после подписчика)
# Epoch 4/60
# 402837/402837 [==============================] - 52s 130us/step - loss: 1.3457
#
# хаха что то что ты на полетельные так и с каликом отдых под калик и под калик в колбу собрались в кальянной полетел он с калика под каликом подписчика)
# Epoch 5/60
# 402837/402837 [==============================] - 52s 130us/step - loss: 1.3174
#
# обратительный дымок с делайте с каликом и под намения самого кумарного дыма и вообще калик под каликом на размер в кальянной воду и покурить кальянчик на своим колбу на своим кальянных на кальянных на кальянных на кальянных братики по кайфу можно и под намению в своему такого кумарные кальяндусика 💨💨💨 всем дымного брата, а то то не просто покурить кальянчик под руки по кайфу кралечки и под каликов@@@
# Epoch 6/60
# 402837/402837 [==============================] - 52s 130us/step - loss: 1.2914
#
#  как говорится сейчас поможет вейп и подруга вы по кайфу кралечки и поделится как говорится в кальянной покурит и дымок в кальянной под кальянных угольками и покурить калик подругать на дымом и подписчика и подруга в кальянной покурит кальян и кальянных всегда на калик в кальянной покурит 😎😎 не видно что на столовующих кралечки и подобрать в кальянной не подумали в кальянной на под кальянных калик@@@
# Epoch 7/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.2695
#
# хорошо же моя бы на дымной франце с дымной пятницы, а то уже под навивать на дымной пятницу разбьют и под каликом на тройную кальянбусиком кальяндусика по настоящей кальян и под нашей кралей целые кальян кумарного кальянбуса за то что такого кальянбуса за то как говорится ставь дымного кальяндуса в кальянной на каликом не под нам под ноги в кальянной покурить кальянщиков дымный кальянодым приколис@@@
# Epoch 8/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.2545
#
# ох уж этот покурить кальян вы понял покурить кальян дымоведенку с кальянной на кальянной в рекомендациях после того парниша на своих кальянный молодежь, пока дым в кальянной в колбу курить кальяндусик для покура об этом колбасит дарксайда и в дом не под кольяндосило плотного дымком💨💨 на кальяндусик далбоподской сидери 💨💨💨 маломило полного дымного дыма и дымного дымка 💨💨💨 в дымном забивочки и калья@@@
# Epoch 9/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.2401
#
# а пацаны ты на кальянные калик в кальянную и покурить калик подписчика)
# Epoch 10/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.2251
#
#  пока дымного кальяндуса в кальянной в порядок с полной кальянбусик бел в колесона и выше в свой первый кальянщик потом под калик на кальянной покурим калик и выручалось кальянщики под калик подуть в кальянной под такой покурим калик на кальянной воду и показывает на полетственник попал не посторонного дымного калямбучи😎😎 в дымом собрание в своей кальянный покурить кальянщики под рукой у тебя кали@@@
# Epoch 11/60
# 402837/402837 [==============================] - 52s 130us/step - loss: 1.2092
#
#  как говорил вот и по кайфу в рекомендациях в дабл эпл на прикольный дым вечер всем продалистым кальяндусик на своем лице стали не по кайфу в порядок не промах не видно принять в руке не поняли от подписчика)
# Epoch 12/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.1957
#
# хахахахахаха?😅😅 правильно стали не просто не подумали в кальянной на просто на кальянной парень и подписчик раз дымного кальянбаса, а то смотрится в кальянной на столе колечко покурим кальянчик и под кальяном, а не по кайфу привет кальяном на кальянбургу представить кальянчик подуть)
# -дорогая кальян приятно отдыхает с кальяном на кальяном и подписчика в кальянной не подумали в кальянной на кальянб@@@
# Epoch 13/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.1819
#
# хахахаха пацаны да по наш пиком не помелить парни правильные кумарные кальяндусик с двойным яблоком 🍎🍏🍎🍏 и все просто тут дарксайдовича по полной и под калик подуть)
# Epoch 14/60
# 402837/402837 [==============================] - 53s 131us/step - loss: 1.1721
#
# пацаны зачем собрались кальяндусик для кумара 💨💨💨 а не по кайфу краля на столовне стало свою кальянной покурит и кальян на добрых не подумали в кальянной-мастер вот и покурить кальянчика - все же облаковость на стол кольца по кайфу улетели и сочного кальянбуса и давай сама под умались кальяндусик для кумара 💨💨💨 а не по кайфу выдели просто в сочи в рекомендациях в полной кальянной, но не то что он @@@
# Epoch 15/60
# 402837/402837 [==============================] - 52s 129us/step - loss: 1.1619
#
# пока дымите кальянчик покурим кальянные конечно хорошо💭💭💭💭 не по кайфу приходит в кальянной забивочек и кальян и просто на приколы и не просто прикола кальянчик и вот и старый до слез😭.... кальян и все под каликом то не просто придумать кальянчик под калик на столе который будет под ростве что надо деньги кальянчик поставил что ты на просто надо святого пыха, кальян не отдыхать братишкам и покурит@@@
# Epoch 16/60
# 307200/402837 [=====================>........] - ETA: 12s - loss: 1.1463
