# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

import json
import re
# Out:
# Using TensorFlow backend.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %%
BEFORE_START = '\0'
AFTER_END = '\1'
def preproc(s):
    s = BEFORE_START + s + AFTER_END
    s = re.sub(r'\[.*\|.*\]', ' ', s)
    s = re.sub(r'[«»]', '"', s)
    return s.lower()

SEQ_LENGTH = 10

# %%
def read_vk_json(s, post_likes_min=0, comment_likes_min=0):
    with open(s, 'r') as f:
        posts = json.load(f)

    texts = []
    for p in posts:
        ptext = p['text'].strip()
        if len(ptext) > SEQ_LENGTH and p['likesCount'] >= post_likes_min:
            texts.append(ptext)

        for c in p['comments']:
            ctext = c['text'].strip()
            if c['likesCount'] >= comment_likes_min and len(ctext) > SEQ_LENGTH:
                texts.append(ctext)

    return [preproc(x) for x in texts]

# %%
kalik_texts = read_vk_json('data/kalikfan.json', comment_likes_min=5)
print('Number of Kalik samples:', len(kalik_texts))
# Out:
# Number of Kalik samples: 1899

# %%
jumoreski_texts = read_vk_json('data/jumoreski.json', 1600)
print('Number of Jumoreski samples:', len(jumoreski_texts))
# Out:
# Number of Jumoreski samples: 9626

# %%
texts = kalik_texts # + jumoreski_texts
print('texts:', len(texts))
# Out:
# texts: 1899

# %%
chars = sorted(list(set(''.join(texts))))
print('total chars before dropping rare:', len(chars))
# Out:
# total chars before dropping rare: 870

# %%
nums = {}
for c in chars:
    for t in texts:
        if c in t:
            if c not in nums:
                nums[c] = 0
            nums[c] += 1
            
MIN_OCCURANCES = 7

for c in chars:
    if nums[c] < MIN_OCCURANCES:
        texts = list(map(lambda t: t.replace(c, ''), texts))
            
nums = {}
for c in chars:
    for t in texts:
        if c in t:
            if c not in nums:
                nums[c] = 0
            nums[c] += 1
            
sorted( ((v,k) for k,v in nums.items()), reverse=False)
# Out:
# [(7, '☀'),
#  (7, '🇧'),
#  (7, '🌳'),
#  (7, '🍁'),
#  (7, '🍋'),
#  (7, '🏋'),
#  (7, '🐎'),
#  (7, '🐩'),
#  (7, '👁'),
#  (7, '👈'),
#  (7, '👠'),
#  (7, '👪'),
#  (7, '👫'),
#  (7, '👷'),
#  (7, '💁'),
#  (7, '💕'),
#  (7, '💙'),
#  (7, '💜'),
#  (7, '💰'),
#  (7, '🔫'),
#  (7, '🗯'),
#  (7, '😒'),
#  (7, '😙'),
#  (7, '😚'),
#  (7, '😣'),
#  (7, '😧'),
#  (7, '😮'),
#  (7, '🤥'),
#  (7, '🤰'),
#  (7, '🧞'),
#  (7, '🧠'),
#  (8, '🇴'),
#  (8, '🌑'),
#  (8, '🍒'),
#  (8, '💄'),
#  (8, '💅'),
#  (8, '💎'),
#  (8, '🔮'),
#  (8, '🗣'),
#  (8, '😖'),
#  (8, '🤑'),
#  (8, '🤖'),
#  (8, '🤷'),
#  (9, '8'),
#  (9, '_'),
#  (9, 'v'),
#  (9, '⛄'),
#  (9, '❌'),
#  (9, '🌞'),
#  (9, '🎤'),
#  (9, '🐔'),
#  (9, '💆'),
#  (9, '💔'),
#  (9, '💧'),
#  (9, '💫'),
#  (9, '😐'),
#  (9, '😥'),
#  (9, '😴'),
#  (9, '😻'),
#  (9, '🙉'),
#  (9, '🤭'),
#  (9, '🥝'),
#  (9, '🥵'),
#  (9, '🥺'),
#  (10, '6'),
#  (10, '‼'),
#  (10, '⚡'),
#  (10, '🇪'),
#  (10, '🇭'),
#  (10, '🇿'),
#  (10, '🍆'),
#  (10, '🍺'),
#  (10, '🏃'),
#  (10, '🐰'),
#  (10, '🐲'),
#  (10, '👵'),
#  (10, '🙂'),
#  (10, '🙋'),
#  (10, '🤟'),
#  (10, '🤫'),
#  (10, '🥰'),
#  (11, '9'),
#  (11, 'w'),
#  (11, 'x'),
#  (11, '☠'),
#  (11, '✨'),
#  (11, '🇲'),
#  (11, '🇹'),
#  (11, '🌝'),
#  (11, '🍅'),
#  (11, '👸'),
#  (11, '👺'),
#  (11, '💯'),
#  (11, '🖤'),
#  (11, '😠'),
#  (11, '😩'),
#  (11, '🙌'),
#  (11, '🚬'),
#  (11, '🤐'),
#  (11, '🤕'),
#  (11, '🤧'),
#  (12, '❗'),
#  (12, '🎅'),
#  (12, '👏'),
#  (12, '👽'),
#  (12, '😬'),
#  (12, '🙀'),
#  (12, '🤨'),
#  (12, '🤮'),
#  (12, '🥴'),
#  (13, '7'),
#  (13, '🇾'),
#  (13, '🍊'),
#  (13, '🐇'),
#  (13, '👧'),
#  (13, '😓'),
#  (13, '😘'),
#  (13, '😭'),
#  (13, '🙊'),
#  (14, 'f'),
#  (14, '✋'),
#  (14, '🌍'),
#  (14, '👮'),
#  (14, '😑'),
#  (14, '😵'),
#  (14, '🙈'),
#  (14, '🚀'),
#  (15, '⛔'),
#  (15, '🇰'),
#  (15, '👅'),
#  (15, '👆'),
#  (15, '👉'),
#  (15, '💋'),
#  (15, '💣'),
#  (15, '💦'),
#  (15, '😛'),
#  (15, '😲'),
#  (15, '🙆'),
#  (15, '🚫'),
#  (16, '5'),
#  (16, '✈'),
#  (16, '🇨'),
#  (16, '🇵'),
#  (16, '🍌'),
#  (16, '😸'),
#  (16, '🙄'),
#  (16, '🤦'),
#  (17, '🍑'),
#  (17, '👦'),
#  (17, '💂'),
#  (17, '🥳'),
#  (17, '🧐'),
#  (18, '#'),
#  (18, '🇦'),
#  (18, '👯'),
#  (18, '👴'),
#  (18, '😔'),
#  (19, '👬'),
#  (19, '👹'),
#  (19, '💀'),
#  (19, '🕺'),
#  (20, '👱'),
#  (20, '😢'),
#  (20, '🤛'),
#  (20, '🤜'),
#  (20, '🤝'),
#  (21, '🍉'),
#  (21, '🏳'),
#  (21, '👄'),
#  (21, '👑'),
#  (21, '👶'),
#  (21, '👻'),
#  (22, '👿'),
#  (23, '⚠'),
#  (23, '🆘'),
#  (23, '🇸'),
#  (23, '🏿'),
#  (24, '4'),
#  (24, 'y'),
#  (24, '💩'),
#  (24, '😰'),
#  (24, '🙅'),
#  (24, '🤬'),
#  (24, '🤯'),
#  (25, 'g'),
#  (25, 'ъ'),
#  (25, '🇫'),
#  (25, '🇮'),
#  (25, '😹'),
#  (26, '🌫'),
#  (26, '👳'),
#  (26, '🤡'),
#  (27, '✊'),
#  (27, '🏽'),
#  (27, '🏾'),
#  (27, '💃'),
#  (28, 'h'),
#  (28, '🇳'),
#  (28, '🌈'),
#  (28, '🌚'),
#  (28, '🌬'),
#  (28, '🤗'),
#  (29, '😨'),
#  (30, '🤘'),
#  (31, '😇'),
#  (31, '🤩'),
#  (34, 'c'),
#  (34, '👩'),
#  (34, '🤓'),
#  (35, '👎'),
#  (35, '💥'),
#  (36, '😺'),
#  (37, 'b'),
#  (37, 'm'),
#  (37, 'p'),
#  (37, '🤔'),
#  (38, '👨'),
#  (40, 't'),
#  (41, '😝'),
#  (42, '2'),
#  (42, '🇱'),
#  (42, '👀'),
#  (43, '3'),
#  (44, 'k'),
#  (44, '🌪'),
#  (45, '✌'),
#  (45, '🔞'),
#  (46, '😄'),
#  (46, '🤢'),
#  (46, '🤤'),
#  (48, '1'),
#  (48, 'd'),
#  (48, '🤠'),
#  (49, 'u'),
#  (50, '—'),
#  (50, '❤'),
#  (52, '🤪'),
#  (53, 'n'),
#  (53, 's'),
#  (53, '☺'),
#  (54, '0'),
#  (55, 'i'),
#  (55, 'l'),
#  (55, '☁'),
#  (57, 'r'),
#  (58, '😉'),
#  (58, '😳'),
#  (59, 'o'),
#  (59, '👊'),
#  (60, '😊'),
#  (63, '🙏'),
#  (67, '😋'),
#  (67, '😏'),
#  (68, '😆'),
#  (69, '🇺'),
#  (70, '😼'),
#  (73, '😜'),
#  (75, 'e'),
#  (77, '😱'),
#  (83, '🇷'),
#  (83, '😡'),
#  (84, '♂'),
#  (84, '👌'),
#  (84, '😀'),
#  (85, '♀'),
#  (86, 'a'),
#  (88, ':'),
#  (92, '😍'),
#  (93, '😁'),
#  (93, '😌'),
#  (99, '"'),
#  (101, '🏼'),
#  (102, '🔥'),
#  (119, '😤'),
#  (123, '💭'),
#  (125, '😃'),
#  (150, '☝'),
#  (162, '😂'),
#  (164, '*'),
#  (170, '🍎'),
#  (174, '('),
#  (179, '🍏'),
#  (183, '\u200d'),
#  (183, '💪'),
#  (192, '👍'),
#  (194, '🤣'),
#  (208, '🏻'),
#  (216, '😅'),
#  (227, '😈'),
#  (247, '️'),
#  (273, '😎'),
#  (276, '🤙'),
#  (283, '!'),
#  (338, '?'),
#  (349, '.'),
#  (369, '💨'),
#  (401, 'ё'),
#  (448, 'ф'),
#  (562, 'щ'),
#  (614, '-'),
#  (616, 'э'),
#  (624, 'ц'),
#  (775, '\n'),
#  (794, ')'),
#  (813, 'ю'),
#  (984, ','),
#  (1030, 'ш'),
#  (1071, 'ж'),
#  (1083, 'х'),
#  (1208, 'з'),
#  (1267, 'г'),
#  (1284, 'й'),
#  (1315, 'ч'),
#  (1440, 'ь'),
#  (1470, 'б'),
#  (1470, 'ы'),
#  (1507, 'я'),
#  (1524, 'п'),
#  (1590, 'д'),
#  (1602, 'м'),
#  (1613, 'в'),
#  (1629, 'у'),
#  (1634, 'с'),
#  (1714, 'л'),
#  (1723, 'р'),
#  (1740, 'н'),
#  (1749, 'к'),
#  (1764, 'и'),
#  (1769, 'т'),
#  (1770, 'е'),
#  (1804, 'о'),
#  (1840, 'а'),
#  (1888, ' '),
#  (1899, '\x00'),
#  (1899, '\x01')]

# %%
chars = sorted(list(set(''.join(texts))))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 335

# %%
# cut the text in semi-redundant sequences of maxlen characters
sentences = []
next_chars = []

for text in texts:
    t = [BEFORE_START] * (SEQ_LENGTH - 1) + list(text) + [AFTER_END] * SEQ_LENGTH
    for i in range(1, len(t) - SEQ_LENGTH, 1):
        sentences.append(t[i:i + SEQ_LENGTH])
        next_chars.append(t[i + SEQ_LENGTH])

# for i in range(0, len(text) - maxlen, step):
#     sentences.append(text[i: i + maxlen])
#     next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 329671

# %%
print('Vectorization...')
x = np.zeros((len(sentences), SEQ_LENGTH, len(chars)), dtype=np.bool)
y = []
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y.append(char_indices[next_chars[i]])
y = np.array(y)
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(SEQ_LENGTH, len(chars)), return_sequences=True))
model.add(Flatten())
model.add(Dense(1024, activation='sigmoid'))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# Build model...

# %%
optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.random.choice(np.arange(0, len(chars)), 1, False, preds)[0]

# %%
def on_epoch_end(epoch, _):
#     if epoch % 10 != 0:
#         return
    # Function invoked at end of each epoch. Prints generated text.
    print()
    # print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - SEQ_LENGTH - 1)
    
    diversity = 0.5
    
    # print('----- diversity:', diversity)

    generated = ''
    sentence = ''.join([BEFORE_START] * SEQ_LENGTH)

    finished_well = False
    for i in range(400):
        x_pred = np.zeros((1, SEQ_LENGTH, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        if next_char == AFTER_END:
            finished_well = True
            break

        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    if not finished_well:
        sys.stdout.write('@@@')
        sys.stdout.flush()
    print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=2048,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 329671/329671 [==============================] - 7s 21us/step - loss: 3.5997
#
#  уо сзон и к сканккнии и ко ково осой  о им но  б ом н  зи м теулк иккиккоют симнеа  ти л реи  онмаоим кон ясннтя е снлм  ип а   имл йие   нм ано  о гк илем еинн кн ларнуогь некноа ватбмро микм  т   сснишс  аал рнам ма на к к  еатоа каокмлоас иктокакио мкамстеск с  ккз тнк ннак анн ро оттннтм д мт н к к  а кнаме  нлооекм листве  ииу и аавзт сбга а ооп и ь нкити со дмвнда нан срр оа лаи уоас к л е @@@
# Epoch 2/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 2.7007
#
# хостчик бабета на демной дымного не дро заблать в тальком за кальянной порестаннак сварнуй накивой кальян сраст всем не поспоходот не порнина похосстолов не покрали сторной кальяндана на корамном походной кальянной поспонь завен луйт смоне в - не тем не кальянчик сладной в понником походвай братем порен лашем сторали за на сваем кальянной всем не своем вайскай и подного у тобо забувать на скумарны@@@
# Epoch 3/60
# 329671/329671 [==============================] - 7s 20us/step - loss:
60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.5049
#
# это не кальянщик пьер ля кумар скумарило плотная какие-то дымократа угольки - миссия не из простых
# ныч в красиво тупа пухло потная крали нелованчы, что он и с них сладких паровоз мундштуканского качества, вспомнил что по кайфу сидим, братья курумбел в зембеюл 🙈 на как подписан, и, на прогих можно 🤩😍😍 и сладкого дыма и придерживает как надо с мы не аромат 🤬🤢🍑🍑что задоласить, а потом митину покутиву@@@
# Epoch 22/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.4754
#
# эх, ну и кальяновый вещи просты перебирает 🤙🤙🤙 не кальянную морозоли двух газокля вот играминиты  рестратов на обсера из ходяешь его* 😱
# -, сли и пыхтиты друг то, с дымным другом и вамете
# Epoch 23/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.4519
#
# 🌫🌫🌫 додрыга давай с нами синя братик на свещенный🤙🏻
# а просто трахер в скругф сочки чтоб ни вы что вы думали, народной мудростью😌 - те кто есть🤣
# Epoch 24/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.4307
#
# кальян это мир (aiil)), а довроге кральявать смотрит на кальянный наполнить свои зимывайте дарксайдовича🎅🏾🎅🏾 и его  божественный кальяшка с фальрейски уидись🤣
#
# чихстайкком пыхтяоция со сколько ты пухлый напрягся сильно😅
# расслабься пошутили😎
# Epoch 25/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.4102
#
# 1300ar бероблем дымчанского хочет 🍑🍑 кальяндусик на беку и почему в тайте делает, команчик (бересеком не заплыть надо принимать сладкий дымочек💜🤡 мощного покурчик💥💨💨💨💨
# Epoch 26/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.3948
#
# 🤡😼😊😅😄вооб в уже с говори да и экромендарсон? подобе или русских🤡👯‍♂️, мы все дымляне🌍🌝, живущие по новари за что нас борце "какалинушку милиму 😈😈зачем маккраны  дарксайд😈
# Epoch 27/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.3807
#
# это же кальянчик и служба кальянчика покурить даже без калика забивали😳☝
# emc
# - дымного права: крепостной кальянщики с добрым утром вас)
# Epoch 28/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.3681
#
# 10 легкая сказал главное курите вас свои врама а не садельным родным дымным наслаждение выходит кольцами) 💨💨💨👍🏻🤣🏻💥
# Epoch 29/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.3543
#
# 🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤@@@
# Epoch 30/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.3468
# 👆🏾👍🏻👍🏻👍🏻 что и честреньу кальянчиком, да так, что аж сидя по сделали из размервать жижысовсеннеть😺
# -а нообщей садя просто будет ходят, быше так а потом работяга приколюху с мотелю внет - миксоска до член😭
# всем дымоглотам💭👊 желаю здарный иду контыво подсабить планке?
# -а можно на обдесло предвожить
# ещё и ещё чамона краля вернётся с завода...уж будь добр спроси за эту ху*йнку наступила)
# -дарксайдычо@@@
# Epoch 31/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 0.3371
#
# это по мастур?😋
#
# паря опасных😅😎😎😎 ждираем!
#
# которык удали его покурямбать😌
# ——————
# от подписчика)
# Epoch 32/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 0.3266
#
# 🤤😅пася реазь в общесь, нестоя с пивздаста развлично не помешается🤣😤💨 вон какие беляшь довать.
#
# всем сладкого покура😁😂
# Epoch 33/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 0.3211
#
# 1300aх себе каликом то она выстатила своею изберамию калик и заведут е**т его откадаюсь и упадом, как так можно и не вынулишки кралямся друзья собрались)
# Epoch 34/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.3133
#
# 1300a- б*р воловков, не подумали что кальян из бальне 👊😌брабочки🍏🍎 положил на спор в рот уже друзей (trie) кумарил в теме👍
# Epoch 35/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.3076
#
# 🤡😼😼😼😈😈
#
# сперли блока - это калик☺️
# Epoch 36/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 0.3027
#
# 🤡😼😼😼😈😈
#
# спельивстелян таника и с камиксусить кальянчик)
# Epoch 37/60
# 329671/329671 [==============================] - 7s 20us/step - loss: 0.2981
#
# 130 блять происходит почему я не еду в египет блядь, а?!
# Epoch 38/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2946
#
# это че за буква?)
# -буква дэку свою обливался к кальянопыханя💨💨опят и террнино: кальян джолж скартым😅 простазили просто твой пидоряк"
# ☁☁☁ потращил и какая кинули пацаната-а эх флен бвин калик дуешь, зачет? - душняц и родного кальянбасиком тоже 🌞🌝🌚
# Epoch 39/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2884
#
# 1300a болест раск пивчту в гразнунега торогой в бере*бу, как гостой вон какой ты у меня учиналсв ча подудеть только дымить за от прикол в том, что у вас муйр жесть плотненького☁☁☁ с инострайский жепте оруйоним и если на горьще то релии при кальян☝️☝️☝️☺..
# такие первестать? должен также протекать из шахты так как присасываться и пыхти сочный кальянщиков. вход вейпогермекваетра и почетают что покурю@@@
# Epoch 40/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2852
#
# 13000 гошет родителям потом детить за угольками лучше пукают горят одни травную тибучку под усужбют кальян, но это уже на раскумариться никому 😤а нашему павуку норм, сидит днем бдит за кальян курите?) красааавцы) но забудет удачной кальянбусика в креткие, взобкали много дыма и приятного вечера😝😝😝
# Epoch 41/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2805
#
# 1300miry альбазарос и маскурсик - нас их ими как всегда они спорили чей кальян восвитай малых при нову 😏🌝🤠 всем двойного яблочка дымный друг так и не зароде ит только кралей не хватает.вот только дымотеропией лечи💪️
# Epoch 42/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2790
#
# 100stisk d беляные  что-боки рада фифигирик: . все с дымным 😎💨 решают проблему (trouble) можно исправите что с ними главное ъо кальяндусик дымный джин💭💭💭😈😈😈 лабызям жизнь делать 🔥, полежили на джоешёл и кралю но бабка😼🤣)) никакий паровоз либерах рвет, админгеры и стри быста, порят.
# Epoch 43/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2757
#
# 100rmi-богят сух и мы кумарить не запретит🤙🏼
# Epoch 44/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2722
#
# это такой поставды🍏🍎 и как эти краля нозячка, кто в родной сарайчик, потому что без калипурда)))😆😆😉😆 хотя бы так пробуют жижения теплильняя могу. путь
# Epoch 45/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2670
#
# 1300a-,чайто смахи всех на вень😤
# Epoch 46/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2654
#
# 1300a-ro- на которратопята этот веделе сразу видно не помните обезьянку абу избойную и снюструны уважают такое и пыхтят с благодарностью природе и сладину крали видно печкир, с братва 😅 да и на меня кумарящего дабл а он заравилась на денег и верное чебножка для спацы отващуети забягули в альфакером зайнажешься и рожной не одорого жить счаткать кальянчик с тобой 🤣
#
# дурайога-каласика 🔥🔥🔥 все и завах@@@
# Epoch 47/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2637
#
# 🤯😱😱😱😱
# не такая😩😁😼
# Epoch 48/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2608
#
# 5👊ф, подставали с красным калимдором😋!! всем цвет настроенья красный‼❤✌🏻😎🤙🏻
# Epoch 49/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2602
#
# ❌😼😼 члёд лаганом забивочка просто святой колен истоит!!!🤪полнус сам больше ждёт копил в толете 👀,(как дым тянулям приям жеть надо 😄
# Epoch 50/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2575
#
# 10 кальямбический дым, говореть 💪💪💪 прибести дарксайдовича🎅🏾🎅🏾 и его  божественные как нас вечер испортит💨💨 пацаны берегите себя братья и сестры это самое святое ауе☝️☝️ в первую очередь задымил, вот и лицо у дондыма угрим, чтобы спалось крепче🌑🌑
# приемы препаратов не пропускают) 🙏🏻😎🌪💨💨настоящий кралезвар после чего.... ревно клучитесь😎😎 ну а кальянщик дай наш калямбасик дунули 😝👍. всем сладкого ды@@@
# Epoch 51/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2542
#
# 13 ля кальяйдолловои жителя у бабки оставили, и кальянчик покурим)
# -давай мной пабл обсичо у кальянщики с добрых были 💨💨💨 всем лёгкого пара и хорошего начала недели пацанам)
# Epoch 52/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2558
#
# 10 кальянщик дракон бралошка-с откратить неуподушное миссе  - он женал за втолоско, всем дымных калюсиков💭💭💭
# Epoch 53/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2520
#
# *корпаться эту жром)
# Epoch 54/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2498
#
# 🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤🤤@@@
# Epoch 55/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2484
#
# 10 колечек и заграхате накрыту  новы  зазлал жиска и мысленный напыла тем самым двойным яблоком🍎🍏 и начал тектоник танцевать🌚🐩, ха, вспомнил что⚠, раскуреации все свои деньги👍👍👍репост на стену😍 вок сктой братке напровил. солько сразу видно - краля 👩 молодец 👍 и не стала будет всегда ухрая отребята красные группы? я не навижу эту хуйню придумывать кальянчик по мужски)
# флейтист👍
# Epoch 56/60
# 329671/329671 [==============================] - 6s 19us/step - loss: 0.2461
#
# 😎😎😎чудиса что на никакой калькулямбус на алюминие 🌚🌚🌚 и двух активированных уголька . вмести со своей кралей👩‍👩‍👩‍ — и вот он в храме святого пыхтируер да челку кралек собрался свою кальянную покайфовать, не испортит накурочку подошёт, ранразадникого и мы горы забивочка🔞🔞🔞 нежные от масочки щечьки так и жаждут наполнить свои рты самым сочным💦💦💦,дымным💨💨 и натуральным bananas 🍌🍌🍌
# Epoch 57/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2446
#
# 100rm0, калика, джина-кальянщика петю или калик зарабатывать подрабатывать подрабатываться) походу это членистоного, да табачка забила? мелодёльно) 😁 бильную комментариев ☺️ от любитель он кальян углём немал за двумя зайцами🐇🐇🐇 погонишься, ни одну не надымит авто геройти эта пидертся тот срезлегь 🤘😄😂 ну с такими царицами нужен целый отряд пацанов😅
# Epoch 58/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2422
#
# это че за буква?)
# -буква дэ братишка) вырубай свою виртуальную реальности, баба бога задотных друговскали по дела реально на колбусковы не золью всегда куришь кальян?
# -братишка ты ошибаешься) футбала... ну и самый fанную приобрывают уголёканиками друга на фоноков и теперь не могут)
# Epoch 59/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2436
#
# 1300o-что только за накуром?)
# -пацаненко ты что сперно вообще блять ебнутые как такое собрание от тебя любимая😍
#
# повезить??? калик разбомбил 🙂💪🙏 главного героя с сись будещего кумарного дня и кумакуро срачило псость красиво конечно😅
# но вдыхать калик и не скушёт😂💨
# —
# Epoch 60/60
# 329671/329671 [==============================] - 6s 20us/step - loss: 0.2401
#
# 😱😼😁💭🔞👎
# ну оса или как там его) хуй с ним будет раз в день нашсловом русским кальянбулык☺️☝️ кумары, чужечен! 🌚😑💩
